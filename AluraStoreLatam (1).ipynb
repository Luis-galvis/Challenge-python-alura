# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

print("Ingreso total de cada tienda:")
print(f"Tienda 1: ${ingreso_tienda1:,.2f}")
print(f"Tienda 2: ${ingreso_tienda2:,.2f}")
print(f"Tienda 3: ${ingreso_tienda3:,.2f}")
print(f"Tienda 4: ${ingreso_tienda4:,.2f}")
# Out:
# Ingreso total de cada tienda:
# Tienda 1: $1,150,880,400.00
# Tienda 2: $1,116,343,500.00
# Tienda 3: $1,098,019,600.00
# Tienda 4: $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
print("Productos vendidos por categoría - Tienda 1:")
print(tienda.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False))

print("\nTienda 2:")
print(tienda2.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False))

print("\nTienda 3:")
print(tienda3.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False))

print("\nTienda 4:")
print(tienda4.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False))
# Out:
# Productos vendidos por categoría - Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64
#
# Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64
#
# Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calif_tienda1 = tienda['Calificación'].mean()
calif_tienda2 = tienda2['Calificación'].mean()
calif_tienda3 = tienda3['Calificación'].mean()
calif_tienda4 = tienda4['Calificación'].mean()

print("Calificación promedio de cada tienda:")
print(f"Tienda 1: {calif_tienda1:.2f}")
print(f"Tienda 2: {calif_tienda2:.2f}")
print(f"Tienda 3: {calif_tienda3:.2f}")
print(f"Tienda 4: {calif_tienda4:.2f}")
# Out:
# Calificación promedio de cada tienda:
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Tienda 1
ventas_prod1 = tienda.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("Tienda 1 - Producto más vendido:")
print(ventas_prod1.head(1))
print("Tienda 1 - Producto menos vendido:")
print(ventas_prod1.tail(1))

# Tienda 2
ventas_prod2 = tienda2.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("\nTienda 2 - Producto más vendido:")
print(ventas_prod2.head(1))
print("Tienda 2 - Producto menos vendido:")
print(ventas_prod2.tail(1))

# Tienda 3
ventas_prod3 = tienda3.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("\nTienda 3 - Producto más vendido:")
print(ventas_prod3.head(1))
print("Tienda 3 - Producto menos vendido:")
print(ventas_prod3.tail(1))

# Tienda 4
ventas_prod4 = tienda4.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("\nTienda 4 - Producto más vendido:")
print(ventas_prod4.head(1))
print("Tienda 4 - Producto menos vendido:")
print(ventas_prod4.tail(1))
# Out:
# Tienda 1 - Producto más vendido:
# Producto
# Armario    60
# Name: Producto, dtype: int64
# Tienda 1 - Producto menos vendido:
# Producto
# Auriculares con micrófono    33
# Name: Producto, dtype: int64
#
# Tienda 2 - Producto más vendido:
# Producto
# Iniciando en programación    65
# Name: Producto, dtype: int64
# Tienda 2 - Producto menos vendido:
# Producto
# Juego de mesa    32
# Name: Producto, dtype: int64
#
# Tienda 3 - Producto más vendido:
# Producto
# Kit de bancas    57
# Name: Producto, dtype: int64
# Tienda 3 - Producto menos vendido:
# Producto
# Bloques de construcción    35
# Name: Producto, dtype: int64
#
# Tienda 4 - Producto más vendido:
# Producto
# Cama box    62
# Name: Producto, dtype: int64
# Tienda 4 - Producto menos vendido:
# Producto
# Guitarra eléctrica    33
# Name: Producto, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio1 = tienda['Costo de envío'].mean()
costo_envio2 = tienda2['Costo de envío'].mean()
costo_envio3 = tienda3['Costo de envío'].mean()
costo_envio4 = tienda4['Costo de envío'].mean()

print("Costo de envío promedio de cada tienda:")
print(f"Tienda 1: ${costo_envio1:,.2f}")
print(f"Tienda 2: ${costo_envio2:,.2f}")
print(f"Tienda 3: ${costo_envio3:,.2f}")
print(f"Tienda 4: ${costo_envio4:,.2f}")
# Out:
# Costo de envío promedio de cada tienda:
# Tienda 1: $26,018.61
# Tienda 2: $25,216.24
# Tienda 3: $24,805.68
# Tienda 4: $23,459.46

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=tiendas_nombres, y=ingresos, color="mediumseagreen")  # cambiamos palette por color
plt.title("Ingreso total por tienda")
plt.ylabel("Ingreso total ($)")
plt.show()

# %%
calificaciones = [calif_tienda1, calif_tienda2, calif_tienda3, calif_tienda4]

plt.figure(figsize=(8,5))
sns.barplot(x=tiendas_nombres, y=calificaciones, palette="Set2")
plt.title("Calificación promedio por tienda")
plt.ylabel("Calificación promedio")
plt.ylim(0,5)  # como las calificaciones son de 1 a 5
plt.show()
# Out:
# /tmp/ipykernel_750/1629178531.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=tiendas_nombres, y=calificaciones, palette="Set2")

# %%
ventas_categoria1 = tienda.groupby('Categoría del Producto')['Producto'].count()

plt.figure(figsize=(7,7))
plt.pie(ventas_categoria1, labels=ventas_categoria1.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Distribución de productos vendidos por categoría - Tienda 1")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=tienda, x='Precio', y='Calificación', hue='Categoría del Producto', palette='Set2', s=100)
plt.title("Relación entre Precio y Calificación - Tienda 1")
plt.xlabel("Precio ($)")
plt.ylabel("Calificación")
plt.legend(title="Categoría", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Informe Final de Análisis de Tiendas
#
# Informe Final de Análisis de Tiendas
#
# Introducción
# El objetivo de este análisis es determinar en cuál de las cuatro tiendas debería enfocar sus ventas el Sr. Juan, considerando factores clave que impactan en la rentabilidad y la satisfacción del cliente. Los factores evaluados incluyen:
# - Ingresos totales de cada tienda.
# - Cantidad de productos vendidos por categoría.
# - Calificación promedio de los clientes.
# - Productos más y menos vendidos.
# - Costo de envío promedio.
# Se complementa con gráficos para facilitar la visualización de las tendencias y patrones de cada tienda.
#
# 1. Ingresos totales por tienda
#
#     Tienda 1    $1,150,880,400
#
#     Tienda 2    $1,116,343,500
#
#     Tienda 3    $1,098,019,600
#
#     Tienda 4    $1,038,375,700
#
# La Tienda 1 lidera en ingresos totales, seguida por la Tienda 2, Tienda 3 y finalmente la Tienda 4. Esto indica que la Tienda 1 tiene el mayor volumen de ventas y potencial económico.
# Gráfico recomendado: barra de ingresos totales por tienda.
#
# 2. Productos vendidos por categoría
# Resumen de categorías más vendidas por tienda:
# Tienda 1: Muebles (465), Electrónicos (448), Juguetes (324)
# Tienda 2: Muebles (442), Electrónicos (422), Juguetes (313)
# Tienda 3: Muebles (499), Electrónicos (451), Juguetes (315)
# Tienda 4: Muebles (480), Electrónicos (451), Juguetes (338)
#
# Las categorías de Muebles y Electrónicos dominan todas las tiendas, mientras que categorías como Instrumentos musicales o Artículos para el hogar son menos populares.
# Gráfico recomendado: gráfico de pastel o barras de productos por categoría por tienda.
#
# 3. Calificación promedio de los clientes
#
# Tienda 1    3.98
#
# Tienda 2    4.04
#
# Tienda 3    4.05
#
# Tienda 4    4.00
#
# La Tienda 3 tiene la calificación promedio más alta (4.05), mostrando una buena satisfacción del cliente, mientras que la Tienda 1, a pesar de liderar en ingresos, tiene la calificación promedio más baja (3.98). Esto indica que las ventas altas no necesariamente reflejan la máxima satisfacción del cliente.
# Gráfico recomendado: barra de calificación promedio por tienda.
#
# 4. Productos más y menos vendidos
#
# Tienda 1    Armario                  60          Auriculares con micrófono  33
#
# Tienda 2    Iniciando en programación 65         Juego de mesa              32
#
# Tienda 3    Kit de bancas             57         Bloques de construcción    35
#
# Tienda 4    Cama box                  62         Guitarra eléctrica         33
#
# Identificar los productos más vendidos permite enfocar inventario en artículos rentables. Los menos vendidos podrían requerir promociones o revisión de stock.
# Gráfico recomendado: barras horizontales con top 5 productos por tienda.
#
# 5. Costo de envío promedio
#
# Tienda 1    $26,018.61
#
# Tienda 2    $25,216.24
#
# Tienda 3    $24,805.68
#
# Tienda 4    $23,459.46
#
# La Tienda 4 ofrece los costos de envío más bajos, lo que puede ser un incentivo para atraer clientes, mientras que la Tienda 1 tiene el envío más alto, lo que podría afectar la percepción de valor a pesar de sus altos ingresos.
# Gráfico recomendado: barra de costo de envío promedio por tienda.
#
# Conclusión y recomendación
# Después de analizar todos los factores:
# - Tienda 1: Mayor ingreso total y productos populares, pero calificación ligeramente más baja y costo de envío alto.
# - Tienda 2 y 3: Buen equilibrio entre ingresos, calificación y categorías populares.
# - Tienda 4: Menor ingreso, pero costo de envío más bajo y calificación aceptable.
#
# Recomendación:
# El Sr. Juan debería enfocar sus ventas principalmente en Tienda 1, ya que genera los ingresos más altos y tiene productos con alta demanda. Sin embargo, es recomendable considerar estrategias para mejorar la experiencia del cliente y reducir el impacto del costo de envío elevado. Como alternativa secundaria, la Tienda 3 también es atractiva por su calificación promedio más alta y buena popularidad de productos.
#
# Esta decisión se respalda tanto en los ingresos y ventas de productos como en las visualizaciones gráficas que muestran claramente la superioridad de la Tienda 1 en términos de potencial de venta.
